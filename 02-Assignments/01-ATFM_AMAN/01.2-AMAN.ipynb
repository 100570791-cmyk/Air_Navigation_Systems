# %%
"""
ATFM
@author: Adrian Sanz Mena
"""
# pyright: reportWildcardImportFromLibrary=false

from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
from pyomo.environ import *
from coopr.pyomo import *

# %% [markdown]
# # Function Definition

# %% [markdown]
# Given Functions

# %%
def S_FAP_ini(time_intervals):
    S_FAP = {}
    for t in range(time_intervals+1):  # 0..40
        S_FAP[t] = 1
    return S_FAP

def legs_ini(legs):
    legs["f1"] = (  "(STAR_1,IAF_1)","(IAF_1,FAP)" )
    legs["f2"] = (  "(STAR_1,IAF_1)","(IAF_1,FAP)")
    legs["f3"] = (  "(STAR_1,IAF_1)","(IAF_1,FAP)" )

    legs["f4"] = (  "(STAR_2,IAF_2)","(IAF_2,FAP)" )
    legs["f5"] = (  "(STAR_2,IAF_2)","(IAF_2,FAP)")
    legs["f6"] = (  "(STAR_2,IAF_2)","(IAF_2,FAP)" )

    legs["f7"] = (  "(STAR_3,IAF_3)","(IAF_3,FAP)" )
    legs["f8"] = (  "(STAR_3,IAF_3)","(IAF_3,FAP)")
    legs["f9"] = (  "(STAR_3,IAF_3)","(IAF_3,FAP)" )

    legs["f10"] = (  "(STAR_4,IAF_4)","(IAF_4,FAP)" )
    legs["f11"] = (  "(STAR_4,IAF_4)","(IAF_4,FAP)")
    legs["f12"] = (  "(STAR_4,IAF_4)","(IAF_4,FAP)" )
    
    return legs

def N_f_ini(N_f):
    N_f["f1"]  = ("STAR_1", "IAF_1", "holding_1", "FAP")
    N_f["f2"]  = ("STAR_1", "IAF_1", "holding_1", "FAP")
    N_f["f3"]  = ("STAR_1", "IAF_1", "holding_1", "FAP")

    N_f["f4"]  = ("STAR_2", "IAF_2", "holding_2", "FAP")
    N_f["f5"]  = ("STAR_2", "IAF_2", "holding_2", "FAP")
    N_f["f6"]  = ("STAR_2", "IAF_2", "holding_2", "FAP")

    N_f["f7"]  = ("STAR_3", "IAF_3", "holding_3", "FAP")
    N_f["f8"]  = ("STAR_3", "IAF_3", "holding_3", "FAP")
    N_f["f9"]  = ("STAR_3", "IAF_3", "holding_3", "FAP")

    N_f["f10"] = ("STAR_4", "IAF_4", "holding_4", "FAP")
    N_f["f11"] = ("STAR_4", "IAF_4", "holding_4", "FAP")
    N_f["f12"] = ("STAR_4", "IAF_4", "holding_4", "FAP")

    return N_f

# %% [markdown]
# Self-Made Functions

# %%
def Objective_rule(model):
    return sum(model.STAR_delay[f] + model.hold_delay[f] 
               for f in model.F)

def capacity_constraint(model, t):
    if t==0:
        return Constraint.Skip

    return sum(model.w[f, "FAP", t] - model.w[f, "FAP", t-1] 
               for f in model.F)                               <= model.S_FAP[t]

def flag_constraint(model, f, n, t):
    if t==0:
        return Constraint.Skip
    return model.w[f, n, t-1] <= model.w[f, n, t]

def star_delay(model, f):
    return model.STAR_delay[f] <= model.max_STAR_delay[f]

def hold_delay(model, f):
    return model.hold_delay[f] <= model.max_hold_delay[f]

def arrival_time(model, f):
    arrival_time = model.d_f[f] + model.STAR_delay[f] + model.hold_delay[f]
    
    for leg in model.legs[f]:
        arrival_time += model.legs_time[leg]

    return model.arrival_FAP[f] == arrival_time

def arrival_w_flag(model, f):
    return model.arrival_FAP[f] == sum(
    t * (model.w[f, model.destination_f[f], t] - model.w[f, model.destination_f[f], t-1])
    for t in model.T if t != 0
    )

# %% [markdown]
# # Initialize Variables and Dicts.

# %%
time_intervals = 50

#Sets
T = list(range(time_intervals+1))
F = ['f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12']
K = ['STAR_1', 'STAR_2', 'STAR_3', 'STAR_4', 'FAP']

# Scheduled departure times
d_f = {
       F[0]: 1, 
       F[1]: 2, 
       F[2]: 3,
       F[3]: 1, 
       F[4]: 2, 
       F[5]: 3,
       F[6]: 1, 
       F[7]: 2, 
       F[8]: 3,
       F[9]: 1, 
       F[10]: 2, 
       F[11]: 3,
}

a_f = {
       F[0]: 1+9,
       F[1]: 2+9,
       F[2]: 3+9,
       F[3]: 1+9,
       F[4]: 2+9,
       F[5]: 3+9,
       F[6]: 1+9,
       F[7]: 2+9,
       F[8]: 3+9,
       F[9]: 1+9,
       F[10]: 2+9,
       F[11]: 3+9,
}


legs = {}

# Legs time
legs_time = {
    "(STAR_1,IAF_1)": 4,
    "(IAF_1,FAP)": 5,

    "(STAR_2,IAF_2)": 4,
    "(IAF_2,FAP)": 5,

    "(STAR_3,IAF_3)": 5,
    "(IAF_3,FAP)": 5,
    
    "(STAR_4,IAF_4)": 5,
    "(IAF_4,FAP)": 5
       }

# Origin and Destination Airport
origin_f={}
origin_f[F[0]] = K[0]
origin_f[F[1]] = K[0]
origin_f[F[2]] = K[0]
origin_f[F[3]] = K[1]
origin_f[F[4]] = K[1]
origin_f[F[5]] = K[1]
origin_f[F[6]] = K[2]
origin_f[F[7]] = K[2]
origin_f[F[8]] = K[2]
origin_f[F[9]] = K[3]
origin_f[F[10]] = K[3]
origin_f[F[11]] = K[3]

destination_f={}
destination_f[F[0]] = K[4]
destination_f[F[1]] = K[4]
destination_f[F[2]] = K[4]
destination_f[F[3]] = K[4]
destination_f[F[4]] = K[4]
destination_f[F[5]] = K[4]
destination_f[F[6]] = K[4]
destination_f[F[7]] = K[4]
destination_f[F[8]] = K[4]
destination_f[F[9]] = K[4]
destination_f[F[10]] = K[4]
destination_f[F[11]] = K[4]


# Max STAR delay for flight f
max_STAR_delay={}
for f in F:
    max_STAR_delay[f] = 3

# Max hold
max_hold_delay={}
for f in F:
    max_hold_delay[f] = 5

N_f = {}

# %%
############### Create a concrete model ###############
model = ConcreteModel('ATFM')

# %%
############### Initialize Sets and Parameters ###############
############### FEW examples are given below (complete until you get the print that you will find in the cell below) ###############

# pyright: reportAttributeAccessIssue=false 

model.T = Set(initialize=T, ordered=True)
model.F = Set(initialize=F, ordered=True)
model.K = Set(initialize=K, ordered=True)

model.legs      = Param(model.F, initialize=legs_ini(legs))
model.legs_time = Param(legs_time.keys(), initialize=legs_time)
model.S_FAP     = Param(model.T, initialize=S_FAP_ini(time_intervals))
model.N_f       = Set(model.F, initialize=N_f_ini(N_f), ordered=True)

model.d_f = Param(d_f.keys(), initialize=d_f)

model.origin_f = Param(model.F, initialize=origin_f)
model.destination_f = Param(model.F, initialize=destination_f)

model.max_STAR_delay = Param(model.F, initialize=max_STAR_delay)
model.max_hold_delay = Param(model.F, initialize=max_hold_delay)

model.STAR_delay = Var(model.F, bounds=(0, None), initialize=0)
model.hold_delay = Var(model.F, bounds=(0, None), initialize=0)

model.arrival_FAP = Var(model.F, within=Reals)

# %%
var = {}


# Ahora definimos la variable binaria en Pyomo solo para estos pares
model.w = Var(
    [(f,n) 
     for f in model.F 
     for n in model.N_f[f]],
    model.T,
    within=Binary,
    initialize=0
)

# %%
### Define Objective Function ###

# pyright: reportAttributeAccessIssue=false

model.objective_func = Objective(rule=Objective_rule, sense=minimize)

# %%
# pyright: reportAttributeAccessIssue=false
# pyright: reportArgumentType=false
# pyright: reportIndexIssue=false

# Vuelos maximos en FAP <= Capcidad maxima (1)
model.capacity_constraint     = Constraint(model.T, rule=capacity_constraint)

model.T_combined = Set(dimen=3, initialize=lambda model: [
    (f, n, t) 
    for f in model.F 
    for n in model.N_f[f] 
    for t in model.T
])
# W es cumulativa
model.flag_constraint         = Constraint(model.T_combined, rule=flag_constraint) 

# Delay de F tiene que ser menor que el maximo (5)
model.star_delay_constraint   = Constraint(model.F, rule=star_delay)

# Hold de f tiene que ser menor que el maximo (3)
model.hold_delay_constraint   = Constraint(model.F, rule=hold_delay)

# Tiempo de llegada = salida + star_delay + hold + tiempos de recorrer legs
model.arrival_time_constraint = Constraint(model.F, rule=arrival_time)

# Tiempo de llegada = -1t * (w = -1)
model.link_arrival_constraint = Constraint(model.F, rule=arrival_w_flag)

# %%
# Solver call
# pyright: reportAttributeAccessIssue=false

solver = SolverFactory('glpk')
#solver = SolverFactory('cplex_direct')
result = solver.solve(model)
pyomo.environ.value(model.objective_func)

objective_val = model.objective_func()
print("Objective value after minimizing:", objective_val)

# %%
# Prints: one can print the complete model or just some elements of it
model.arrival_FAP.pprint()
# Out:
# arrival_FAP : Size=12, Index=F
#     Key : Lower : Value : Upper : Fixed : Stale : Domain
#      f1 :  None :  None :  None : False :  True :  Reals
#     f10 :  None :  None :  None : False :  True :  Reals
#     f11 :  None :  None :  None : False :  True :  Reals
#     f12 :  None :  None :  None : False :  True :  Reals
#      f2 :  None :  None :  None : False :  True :  Reals
#      f3 :  None :  None :  None : False :  True :  Reals
#      f4 :  None :  None :  None : False :  True :  Reals
#      f5 :  None :  None :  None : False :  True :  Reals
#      f6 :  None :  None :  None : False :  True :  Reals
#      f7 :  None :  None :  None : False :  True :  Reals
#      f8 :  None :  None :  None : False :  True :  Reals
#      f9 :  None :  None :  None : False :  True :  Reals

# %%
model.w.pprint()
# Out:
# w : Size=1836, Index={('f1', 'STAR_1'), ('f1', 'IAF_1'), ('f1', 'FAP'), ('f2', 'STAR_1'), ('f2', 'IAF_1'), ('f2', 'FAP'), ('f3', 'STAR_1'), ('f3', 'IAF_1'), ('f3', 'FAP'), ('f4', 'STAR_2'), ('f4', 'IAF_2'), ('f4', 'FAP'), ('f5', 'STAR_2'), ('f5', 'IAF_2'), ('f5', 'FAP'), ('f6', 'STAR_2'), ('f6', 'IAF_2'), ('f6', 'FAP'), ('f7', 'STAR_3'), ('f7', 'IAF_3'), ('f7', 'FAP'), ('f8', 'STAR_3'), ('f8', 'IAF_3'), ('f8', 'FAP'), ('f9', 'STAR_3'), ('f9', 'IAF_3'), ('f9', 'FAP'), ('f10', 'STAR_4'), ('f10', 'IAF_4'), ('f10', 'FAP'), ('f11', 'STAR_4'), ('f11', 'IAF_4'), ('f11', 'FAP'), ('f12', 'STAR_4'), ('f12', 'IAF_4'), ('f12', 'FAP')}*T
#     Key                   : Lower : Value : Upper : Fixed : Stale : Domain
#          ('f1', 'FAP', 0) :     0 :     0 :     1 : False : False : Binary
#          ('f1', 'FAP', 1) :     0 :     0 :     1 : False : False : Binary
#          ('f1', 'FAP', 2) :     0 :     0 :     1 : False : False : Binary
#          ('f1', 'FAP', 3) :     0 :     0 :     1 : False : False : Binary
#          ('f1', 'FAP', 4) :     0 :     0 :     1 : False : False : Binary
#          ('f1', 'FAP', 5) :     0 :     0 :     1 : False : False : Binary
#          ('f1', 'FAP', 6) :     0 :     0 :     1 : False : False : Binary
#          ('f1', 'FAP', 7) :     0 :     0 :     1 : False : False : Binary
#          ('f1', 'FAP', 8) :     0 :     0 :     1 : False : False : Binary
#          ('f1', 'FAP', 9) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 10) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 11) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 12) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 13) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 14) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 15) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 16) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 17) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 18) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 19) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 20) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 21) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 22) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 23) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 24) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 25) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 26) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 27) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 28) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 29) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 30) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 31) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 32) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 33) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 34) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 35) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 36) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 37) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 38) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 39) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 40) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 41) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 42) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 43) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 44) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 45) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 46) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 47) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 48) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 49) :     0 :     0 :     1 : False : False : Binary
#         ('f1', 'FAP', 50) :     0 :     0 :     1 : False : False : Binary
#        ('f1', 'IAF_1', 0) :     0 :     0 :     1 : False : False : Binary
#        ('f1', 'IAF_1', 1) :     0 :     0 :     1 : False : False : Binary
#        ('f1', 'IAF_1', 2) :     0 :     0 :     1 : False : False : Binary
#        ('f1', 'IAF_1', 3) :     0 :     0 :     1 : False : False : Binary
#        ('f1', 'IAF_1', 4) :     0 :     0 :     1 : False : False : Binary
#        ('f1', 'IAF_1', 5) :     0 :     0 :     1 : False : False : Binary
#        ('f1', 'IAF_1', 6) :     0 :     0 :     1 : False : False : Binary
#        ('f1', 'IAF_1', 7) :     0 :     0 :     1 : False : False : Binary
#        ('f1', 'IAF_1', 8) :     0 :     0 :     1 : False : False : Binary
#        ('f1', 'IAF_1', 9) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 10) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 11) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 12) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 13) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 14) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 15) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 16) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 17) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 18) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 19) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 20) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 21) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 22) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 23) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 24) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 25) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 26) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 27) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 28) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 29) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 30) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 31) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 32) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 33) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 34) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 35) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 36) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 37) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 38) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 39) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 40) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 41) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 42) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 43) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 44) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 45) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 46) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 47) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 48) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 49) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'IAF_1', 50) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'STAR_1', 0) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'STAR_1', 1) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'STAR_1', 2) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'STAR_1', 3) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'STAR_1', 4) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'STAR_1', 5) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'STAR_1', 6) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'STAR_1', 7) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'STAR_1', 8) :     0 :     0 :     1 : False : False : Binary
#       ('f1', 'STAR_1', 9) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 10) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 11) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 12) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 13) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 14) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 15) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 16) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 17) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 18) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 19) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 20) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 21) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 22) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 23) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 24) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 25) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 26) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 27) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 28) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 29) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 30) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 31) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 32) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 33) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 34) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 35) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 36) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 37) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 38) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 39) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 40) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 41) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 42) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 43) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 44) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 45) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 46) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 47) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 48) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 49) :     0 :     0 :     1 : False : False : Binary
#      ('f1', 'STAR_1', 50) :     0 :     0 :     1 : False : False : Binary
#         ('f10', 'FAP', 0) :     0 :     0 :     1 : False : False : Binary
#         ('f10', 'FAP', 1) :     0 :     0 :     1 : False : False : Binary
#         ('f10', 'FAP', 2) :     0 :     0 :     1 : False : False : Binary
#         ('f10', 'FAP', 3) :     0 :     0 :     1 : False : False : Binary
#         ('f10', 'FAP', 4) :     0 :     0 :     1 : False : False : Binary
#         ('f10', 'FAP', 5) :     0 :     0 :     1 : False : False : Binary
#         ('f10', 'FAP', 6) :     0 :     0 :     1 : False : False : Binary
#         ('f10', 'FAP', 7) :     0 :     0 :     1 : False : False : Binary
#         ('f10', 'FAP', 8) :     0 :     0 :     1 : False : False : Binary
#         ('f10', 'FAP', 9) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 10) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 11) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 12) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 13) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 14) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 15) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 16) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 17) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 18) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 19) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 20) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 21) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 22) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 23) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 24) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 25) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 26) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 27) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 28) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 29) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 30) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 31) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 32) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 33) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 34) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 35) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 36) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 37) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 38) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 39) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 40) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 41) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 42) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 43) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 44) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 45) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 46) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 47) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 48) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 49) :     0 :     0 :     1 : False : False : Binary
#        ('f10', 'FAP', 50) :     0 :     0 :     1 : False : False : Binary
#       ('f10', 'IAF_4', 0) :     0 :     0 :     1 : False : False : Binary
#       ('f10', 'IAF_4', 1) :     0 :     0 :     1 : False : False : Binary
#       ('f10', 'IAF_4', 2) :     0 :     0 :     1 : False : False : Binary
#       ('f10', 'IAF_4', 3) :     0 :     0 :     1 : False : False : Binary
#       ('f10', 'IAF_4', 4) :     0 :     0 :     1 : False : False : Binary
#       ('f10', 'IAF_4', 5) :     0 :     0 :     1 : False : False : Binary
#       ('f10', 'IAF_4', 6) :     0 :     0 :     1 : False : False : Binary
#       ('f10', 'IAF_4', 7) :     0 :     0 :     1 : False : False : Binary
#       ('f10', 'IAF_4', 8) :     0 :     0 :     1 : False : False : Binary
#       ('f10', 'IAF_4', 9) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 10) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 11) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 12) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 13) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 14) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 15) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 16) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 17) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 18) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 19) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 20) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 21) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 22) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 23) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 24) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 25) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 26) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 27) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 28) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 29) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 30) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 31) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 32) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 33) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 34) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 35) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 36) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 37) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 38) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 39) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 40) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 41) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 42) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 43) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 44) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 45) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 46) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 47) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 48) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 49) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'IAF_4', 50) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'STAR_4', 0) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'STAR_4', 1) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'STAR_4', 2) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'STAR_4', 3) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'STAR_4', 4) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'STAR_4', 5) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'STAR_4', 6) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'STAR_4', 7) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'STAR_4', 8) :     0 :     0 :     1 : False : False : Binary
#      ('f10', 'STAR_4', 9) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 10) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 11) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 12) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 13) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 14) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 15) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 16) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 17) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 18) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 19) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 20) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 21) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 22) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 23) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 24) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 25) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 26) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 27) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 28) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 29) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 30) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 31) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 32) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 33) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 34) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 35) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 36) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 37) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 38) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 39) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 40) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 41) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 42) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 43) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 44) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 45) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 46) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 47) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 48) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 49) :     0 :     0 :     1 : False : False : Binary
#     ('f10', 'STAR_4', 50) :     0 :     0 :     1 : False : False : Binary
#         ('f11', 'FAP', 0) :     0 :     0 :     1 : False : False : Binary
#         ('f11', 'FAP', 1) :     0 :     0 :     1 : False : False : Binary
#         ('f11', 'FAP', 2) :     0 :     0 :     1 : False : False : Binary
#         ('f11', 'FAP', 3) :     0 :     0 :     1 : False : False : Binary
#         ('f11', 'FAP', 4) :     0 :     0 :     1 : False : False : Binary
#         ('f11', 'FAP', 5) :     0 :     0 :     1 : False : False : Binary
#         ('f11', 'FAP', 6) :     0 :     0 :     1 : False : False : Binary
#         ('f11', 'FAP', 7) :     0 :     0 :     1 : False : False : Binary
#         ('f11', 'FAP', 8) :     0 :     0 :     1 : False : False : Binary
#         ('f11', 'FAP', 9) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 10) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 11) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 12) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 13) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 14) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 15) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 16) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 17) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 18) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 19) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 20) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 21) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 22) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 23) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 24) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 25) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 26) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 27) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 28) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 29) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 30) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 31) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 32) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 33) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 34) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 35) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 36) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 37) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 38) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 39) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 40) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 41) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 42) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 43) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 44) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 45) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 46) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 47) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 48) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 49) :     0 :     0 :     1 : False : False : Binary
#        ('f11', 'FAP', 50) :     0 :     0 :     1 : False : False : Binary
#       ('f11', 'IAF_4', 0) :     0 :     0 :     1 : False : False : Binary
#       ('f11', 'IAF_4', 1) :     0 :     0 :     1 : False : False : Binary
#       ('f11', 'IAF_4', 2) :     0 :     0 :     1 : False : False : Binary
#       ('f11', 'IAF_4', 3) :     0 :     0 :     1 : False : False : Binary
#       ('f11', 'IAF_4', 4) :     0 :     0 :     1 : False : False : Binary
#       ('f11', 'IAF_4', 5) :     0 :     0 :     1 : False : False : Binary
#       ('f11', 'IAF_4', 6) :     0 :     0 :     1 : False : False : Binary
#       ('f11', 'IAF_4', 7) :     0 :     0 :     1 : False : False : Binary
#       ('f11', 'IAF_4', 8) :     0 :     0 :     1 : False : False : Binary
#       ('f11', 'IAF_4', 9) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 10) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 11) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 12) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 13) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 14) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 15) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 16) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 17) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 18) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 19) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 20) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 21) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 22) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 23) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 24) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 25) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 26) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 27) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 28) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 29) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 30) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 31) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 32) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 33) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 34) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 35) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 36) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 37) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 38) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 39) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 40) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 41) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 42) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 43) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 44) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 45) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 46) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 47) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 48) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 49) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'IAF_4', 50) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'STAR_4', 0) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'STAR_4', 1) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'STAR_4', 2) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'STAR_4', 3) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'STAR_4', 4) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'STAR_4', 5) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'STAR_4', 6) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'STAR_4', 7) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'STAR_4', 8) :     0 :     0 :     1 : False : False : Binary
#      ('f11', 'STAR_4', 9) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 10) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 11) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 12) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 13) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 14) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 15) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 16) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 17) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 18) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 19) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 20) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 21) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 22) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 23) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 24) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 25) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 26) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 27) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 28) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 29) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 30) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 31) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 32) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 33) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 34) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 35) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 36) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 37) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 38) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 39) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 40) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 41) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 42) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 43) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 44) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 45) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 46) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 47) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 48) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 49) :     0 :     0 :     1 : False : False : Binary
#     ('f11', 'STAR_4', 50) :     0 :     0 :     1 : False : False : Binary
#         ('f12', 'FAP', 0) :     0 :     0 :     1 : False : False : Binary
#         ('f12', 'FAP', 1) :     0 :     0 :     1 : False : False : Binary
#         ('f12', 'FAP', 2) :     0 :     0 :     1 : False : False : Binary
#         ('f12', 'FAP', 3) :     0 :     0 :     1 : False : False : Binary
#         ('f12', 'FAP', 4) :     0 :     0 :     1 : False : False : Binary
#         ('f12', 'FAP', 5) :     0 :     0 :     1 : False : False : Binary
#         ('f12', 'FAP', 6) :     0 :     0 :     1 : False : False : Binary
#         ('f12', 'FAP', 7) :     0 :     0 :     1 : False : False : Binary
#         ('f12', 'FAP', 8) :     0 :     0 :     1 : False : False : Binary
#         ('f12', 'FAP', 9) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 10) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 11) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 12) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 13) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 14) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 15) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 16) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 17) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 18) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 19) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 20) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 21) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 22) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 23) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 24) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 25) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 26) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 27) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 28) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 29) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 30) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 31) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 32) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 33) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 34) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 35) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 36) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 37) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 38) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 39) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 40) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 41) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 42) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 43) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 44) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 45) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 46) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 47) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 48) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 49) :     0 :     0 :     1 : False : False : Binary
#        ('f12', 'FAP', 50) :     0 :     0 :     1 : False : False : Binary
#       ('f12', 'IAF_4', 0) :     0 :     0 :     1 : False : False : Binary
#       ('f12', 'IAF_4', 1) :     0 :     0 :     1 : False : False : Binary
#       ('f12', 'IAF_4', 2) :     0 :     0 :     1 : False : False : Binary
#       ('f12', 'IAF_4', 3) :     0 :     0 :     1 : False : False : Binary
#       ('f12', 'IAF_4', 4) :     0 :     0 :     1 : False : False : Binary
#       ('f12', 'IAF_4', 5) :     0 :     0 :     1 : False : False : Binary
#       ('f12', 'IAF_4', 6) :     0 :     0 :     1 : False : False : Binary
#       ('f12', 'IAF_4', 7) :     0 :     0 :     1 : False : False : Binary
#       ('f12', 'IAF_4', 8) :     0 :     0 :     1 : False : False : Binary
#       ('f12', 'IAF_4', 9) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 10) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 11) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 12) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 13) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 14) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 15) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 16) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 17) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 18) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 19) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 20) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 21) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 22) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 23) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 24) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 25) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 26) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 27) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 28) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 29) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 30) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 31) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 32) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 33) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 34) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 35) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 36) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 37) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 38) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 39) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 40) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 41) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 42) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 43) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 44) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 45) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 46) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 47) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 48) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 49) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'IAF_4', 50) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'STAR_4', 0) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'STAR_4', 1) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'STAR_4', 2) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'STAR_4', 3) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'STAR_4', 4) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'STAR_4', 5) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'STAR_4', 6) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'STAR_4', 7) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'STAR_4', 8) :     0 :     0 :     1 : False : False : Binary
#      ('f12', 'STAR_4', 9) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 10) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 11) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 12) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 13) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 14) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 15) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 16) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 17) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 18) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 19) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 20) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 21) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 22) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 23) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 24) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 25) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 26) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 27) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 28) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 29) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 30) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 31) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 32) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 33) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 34) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 35) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 36) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 37) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 38) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 39) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 40) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 41) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 42) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 43) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 44) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 45) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 46) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 47) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 48) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 49) :     0 :     0 :     1 : False : False : Binary
#     ('f12', 'STAR_4', 50) :     0 :     0 :     1 : False : False : Binary
#          ('f2', 'FAP', 0) :     0 :     0 :     1 : False : False : Binary
#          ('f2', 'FAP', 1) :     0 :     0 :     1 : False : False : Binary
#          ('f2', 'FAP', 2) :     0 :     0 :     1 : False : False : Binary
#          ('f2', 'FAP', 3) :     0 :     0 :     1 : False : False : Binary
#          ('f2', 'FAP', 4) :     0 :     0 :     1 : False : False : Binary
#          ('f2', 'FAP', 5) :     0 :     0 :     1 : False : False : Binary
#          ('f2', 'FAP', 6) :     0 :     0 :     1 : False : False : Binary
#          ('f2', 'FAP', 7) :     0 :     0 :     1 : False : False : Binary
#          ('f2', 'FAP', 8) :     0 :     0 :     1 : False : False : Binary
#          ('f2', 'FAP', 9) :     0 :     0 :     1 : False : False : Binary
#         ('f2', 'FAP', 10) :     0 :     0 :     1 : False : False : Binary
#         ('f2', 'FAP', 11) :     0 :     0 :     1 : False : False : Binary
#         ('f2', 'FAP', 12) :     0 :     0 :     1 : False : False : Binary
#         ('f2', 'FAP', 13) :     0 :     0 :     1 : False : False : Binary
#         ('f2', 'FAP', 14) :     0 :     0 :     1 : False : False : Binary
#         ('f2', 'FAP', 15) :     0 :     0 :     1 : False : False : Binary
#         ('f2', 'FAP', 16) :     0 :     0 :     1 : False : False : Binary
#         ('f2', 'FAP', 17) :     0 :     0 :     1 : False : False : Binary
# ...
#       ('f8', 'IAF_3', 42) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'IAF_3', 43) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'IAF_3', 44) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'IAF_3', 45) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'IAF_3', 46) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'IAF_3', 47) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'IAF_3', 48) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'IAF_3', 49) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'IAF_3', 50) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'STAR_3', 0) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'STAR_3', 1) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'STAR_3', 2) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'STAR_3', 3) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'STAR_3', 4) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'STAR_3', 5) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'STAR_3', 6) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'STAR_3', 7) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'STAR_3', 8) :     0 :     0 :     1 : False : False : Binary
#       ('f8', 'STAR_3', 9) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 10) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 11) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 12) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 13) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 14) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 15) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 16) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 17) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 18) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 19) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 20) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 21) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 22) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 23) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 24) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 25) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 26) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 27) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 28) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 29) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 30) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 31) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 32) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 33) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 34) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 35) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 36) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 37) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 38) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 39) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 40) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 41) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 42) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 43) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 44) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 45) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 46) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 47) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 48) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 49) :     0 :     0 :     1 : False : False : Binary
#      ('f8', 'STAR_3', 50) :     0 :     0 :     1 : False : False : Binary
#          ('f9', 'FAP', 0) :     0 :     0 :     1 : False : False : Binary
#          ('f9', 'FAP', 1) :     0 :     0 :     1 : False : False : Binary
#          ('f9', 'FAP', 2) :     0 :     0 :     1 : False : False : Binary
#          ('f9', 'FAP', 3) :     0 :     0 :     1 : False : False : Binary
#          ('f9', 'FAP', 4) :     0 :     0 :     1 : False : False : Binary
#          ('f9', 'FAP', 5) :     0 :     0 :     1 : False : False : Binary
#          ('f9', 'FAP', 6) :     0 :     0 :     1 : False : False : Binary
#          ('f9', 'FAP', 7) :     0 :     0 :     1 : False : False : Binary
#          ('f9', 'FAP', 8) :     0 :     0 :     1 : False : False : Binary
#          ('f9', 'FAP', 9) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 10) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 11) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 12) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 13) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 14) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 15) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 16) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 17) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 18) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 19) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 20) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 21) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 22) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 23) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 24) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 25) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 26) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 27) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 28) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 29) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 30) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 31) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 32) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 33) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 34) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 35) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 36) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 37) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 38) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 39) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 40) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 41) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 42) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 43) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 44) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 45) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 46) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 47) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 48) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 49) :     0 :     0 :     1 : False : False : Binary
#         ('f9', 'FAP', 50) :     0 :     0 :     1 : False : False : Binary
#        ('f9', 'IAF_3', 0) :     0 :     0 :     1 : False : False : Binary
#        ('f9', 'IAF_3', 1) :     0 :     0 :     1 : False : False : Binary
#        ('f9', 'IAF_3', 2) :     0 :     0 :     1 : False : False : Binary
#        ('f9', 'IAF_3', 3) :     0 :     0 :     1 : False : False : Binary
#        ('f9', 'IAF_3', 4) :     0 :     0 :     1 : False : False : Binary
#        ('f9', 'IAF_3', 5) :     0 :     0 :     1 : False : False : Binary
#        ('f9', 'IAF_3', 6) :     0 :     0 :     1 : False : False : Binary
#        ('f9', 'IAF_3', 7) :     0 :     0 :     1 : False : False : Binary
#        ('f9', 'IAF_3', 8) :     0 :     0 :     1 : False : False : Binary
#        ('f9', 'IAF_3', 9) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 10) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 11) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 12) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 13) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 14) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 15) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 16) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 17) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 18) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 19) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 20) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 21) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 22) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 23) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 24) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 25) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 26) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 27) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 28) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 29) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 30) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 31) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 32) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 33) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 34) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 35) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 36) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 37) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 38) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 39) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 40) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 41) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 42) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 43) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 44) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 45) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 46) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 47) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 48) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 49) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'IAF_3', 50) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'STAR_3', 0) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'STAR_3', 1) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'STAR_3', 2) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'STAR_3', 3) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'STAR_3', 4) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'STAR_3', 5) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'STAR_3', 6) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'STAR_3', 7) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'STAR_3', 8) :     0 :     0 :     1 : False : False : Binary
#       ('f9', 'STAR_3', 9) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 10) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 11) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 12) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 13) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 14) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 15) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 16) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 17) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 18) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 19) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 20) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 21) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 22) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 23) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 24) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 25) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 26) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 27) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 28) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 29) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 30) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 31) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 32) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 33) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 34) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 35) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 36) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 37) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 38) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 39) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 40) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 41) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 42) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 43) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 44) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 45) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 46) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 47) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 48) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 49) :     0 :     0 :     1 : False : False : Binary
#      ('f9', 'STAR_3', 50) :     0 :     0 :     1 : False : False : Binary
